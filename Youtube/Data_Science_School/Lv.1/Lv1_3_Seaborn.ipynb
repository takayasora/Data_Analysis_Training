# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### 1.折れ線グラフ

# %%
df_weather = pd.read_csv("weather.csv",index_col="年月日",parse_dates=True)

# %%
df_weather
# Out:
#             平均気温(℃)  降水量の合計(mm)  日照時間(時間)
# 年月日
# 2019-01-01      5.3         0.0       8.9
# 2019-01-02      6.2         0.0       8.7
# 2019-01-03      4.9         0.0       8.9
# 2019-01-04      5.1         0.0       8.9
# 2019-01-05      7.4         0.0       8.9
# 2019-01-06      5.3         0.0       2.7
# 2019-01-07      5.4         0.0       8.8
# 2019-01-08      4.6         0.0       8.5
# 2019-01-09      4.5         0.0       9.0
# 2019-01-10      2.0         0.0       1.8
# 2019-01-11      6.4         0.0       8.8
# 2019-01-12      4.6         0.0       0.0
# 2019-01-13      6.2         0.0       6.6
# 2019-01-14      5.6         0.0       9.1
# 2019-01-15      5.6         0.5       2.9
# 2019-01-16      6.6         0.0       6.8
# 2019-01-17      6.6         0.0       8.8
# 2019-01-18      5.9         0.0       9.2
# 2019-01-19      6.6         0.0       9.0
# 2019-01-20      7.1         0.0       8.1
# 2019-01-21      5.8         0.0       9.2
# ...

# %%
sns.lineplot(data=df_weather)
# Out:
# <AxesSubplot:xlabel='年月日'>
# C:\Users\Owner\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 24180 (\N{CJK UNIFIED IDEOGRAPH-5E74}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Owner\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 26376 (\N{CJK UNIFIED IDEOGRAPH-6708}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Owner\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 26085 (\N{CJK UNIFIED IDEOGRAPH-65E5}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Owner\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 24179 (\N{CJK UNIFIED IDEOGRAPH-5E73}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
#PCに収録されているフォントを確認
from fontTools.ttLib import TTFont
import glob
import sys

codePoint = ord('桜')
#codePoint = 0x685C #Unicodeでのコードポイントを直接指定することもできます。

#フォント名の例 "メイリオ", "Meiryo", "MS Mincho" ,"ＭＳ 明朝", "Arial", "Segoe UI Emoji"
fontName = 'メイリオ'

#■１段階目：フォント名(日本語か英語)からフォントファイルを取得する

fontPath = r'C:\Windows\Fonts'
fontFileName = ''

for fileName in glob.glob(f'{fontPath}\*'):
    if not (fileName.upper().endswith('.TTF') or fileName.upper().endswith('.TTC')):
        #拡張子 .ttf または .ttc 以外のファイルは扱いません。
        continue

    font = TTFont(fileName, fontNumber=0)
    names = font['name'].names

    jpName = ''
    enName = ''

    for name in names:
        #platformID 3 は Windows です。Windowsだけ対応しました。(力尽きました。)
        #https://learn.microsoft.com/ja-jp/typography/opentype/spec/name

        #日本語でのフォント名(存在しない場合もあります) 
        if name.platformID == 3 and name.langID == 0x0411 and name.nameID == 1:
            jpName = name.string.decode('utf-16-be')

        #英語でのフォント名
        if name.platformID == 3 and name.langID == 0x0409 and name.nameID == 1:
            enName = name.string.decode('utf-16-be')

        if jpName == fontName or enName == fontName:
            fontFileName = fileName
            break

    if len(fontFileName) > 0:
        break

else:
    print(f'名前が {fontName} のフォントは見つかりませんでした。')
    sys.exit()

#■2段階目：フォントファイルに文字が収録されているか確認する
print (f'フォントファイル：{fontFileName}')
font = TTFont(fontFileName, fontNumber=0)
cmap = list(font.getBestCmap()) 

letter = chr(codePoint)
if codePoint in cmap:
    #出力例 メイリオ に 桜 (0685C) は収録されています。
    print(f'{fontName} に {letter} ({codePoint:05X}) は収録されています。')
else:
    #出力例 Arial に 桜 (0685C) は収録されていません。
    print(f'{fontName} に {letter} ({codePoint:05X}) は収録されていません。')
# Out:
# フォントファイル：C:\Windows\Fonts\meiryo.ttc
# メイリオ に 桜 (0685C) は収録されています。

# %%
#グラフに日本語を表示
sns.set(font="meiryo")
sns.lineplot(data=df_weather)
# Out:
# <AxesSubplot:xlabel='年月日'>

# %%
sns.set(font="meiryo")
#グラフサイズを変更
plt.figure(figsize=(10,8))
sns.lineplot(data=df_weather)
# Out:
# <AxesSubplot:xlabel='年月日'>

# %%
sns.set(font="meiryo")
#グラフサイズを変更
plt.figure(figsize=(15,8))
sns.lineplot(data=df_weather)
# Out:
# <AxesSubplot:xlabel='年月日'>

# %%
#文字の大きさを変更(４段階で調整可能)
#paper < notebook < talk < poster
sns.set(font="meiryo",context="poster")
plt.figure(figsize=(15,8))
sns.lineplot(data=df_weather)
# Out:
# <AxesSubplot:xlabel='年月日'>

# %%
sns.set(font="meiryo",context="poster")
plt.figure(figsize=(15,8))
#X軸を90度回転させて表示
plt.xticks(rotation=90)
sns.lineplot(data=df_weather)
# Out:
# <AxesSubplot:xlabel='年月日'>

# %%
#背景を白に変更
sns.set(font="meiryo",context="poster",style="white")
plt.figure(figsize=(15,8))
plt.xticks(rotation=90)
sns.lineplot(data=df_weather)
# Out:
# <AxesSubplot:xlabel='年月日'>

# %%
# 下記のURL先で様々なスタイルを学習できます
# https://seaborn.pydata.org/tutorial/aesthetics.html

# %%
#背景を白に変更
sns.set(font="meiryo",context="poster",style="white")
plt.figure(figsize=(15,8))
plt.xticks(rotation=90)
sns.lineplot(data=df_weather[["平均気温(℃)","降水量の合計(mm)"]])
plt.savefig("折れ線グラフ.png")

# %% [markdown]
# ### 2.棒グラフ

# %%
df_score = pd.read_csv("test_score.csv")

# %%
df_score
# Out:
#      名前 クラス  性別  国語  算数  英語  理科  社会
# 0   Aさん  1組  男性  89  65  85  70  88
# 1   Bさん  3組  女性  67  56  81  46  78
# 2   Cさん  1組  男性  52  45  67  67  67
# 3   Dさん  2組  男性  45  96  50  80  67
# 4   Eさん  1組  男性  77  48  67  60  64
# 5   Fさん  2組  女性  60  73  83  60  53
# 6   Gさん  3組  男性  45  56  87  63  67
# 7   Hさん  2組  女性  81  65  90  45  70
# 8   Iさん  3組  女性  76  57  86  50  67
# 9   Jさん  2組  男性  44  96  56  89  71
# 10  Kさん  1組  女性  89  55  82  92  84
# 11  Lさん  2組  女性  31  37  76  45  50
# 12  Mさん  3組  男性  60  53  50  67  65
# 13  Nさん  2組  男性  71  98  81  91  99
# 14  Oさん  1組  男性  53  62  41  57  55
# 15  Pさん  2組  女性  89  83  69  57  44
# 16  Qさん  1組  男性  45  56  30  73  49
# 17  Rさん  3組  女性  64  56  76  50  69
# 18  Sさん  1組  女性  42  57  56  33  61
# 19  Tさん  2組  男性  76  90  66  67  89
# 20  Uさん  2組  男性  89  98  92  83  66
# 21  Vさん  1組  男性  65  58  62  50  53
# 22  Wさん  1組  男性  44  46  61  56  65
# 23  Xさん  3組  女性  76  56  34  65  67
# 24  Yさん  2組  男性  93  87  56  90  64
# ...

# %%
#何も指定しない場合、科目別の平均点を計算して、出力（棒は範囲）
sns.barplot(data=df_score)
# Out:
# <AxesSubplot:>

# %%
#X軸とY軸を指定
sns.barplot(data=df_score,x="名前",y="国語")
# Out:
# <AxesSubplot:xlabel='名前', ylabel='国語'>

# %%
sns.set(font="meiryo",context="talk")
sns.barplot(data=df_score,x="名前",y="国語")
# Out:
# <AxesSubplot:xlabel='名前', ylabel='国語'>

# %%
#項目軸の入れ替えを行いたい場合、単純にxとyを書き換える
sns.set(font="meiryo",context="talk")
sns.barplot(data=df_score,y="名前",x="国語")
# Out:
# <AxesSubplot:xlabel='国語', ylabel='名前'>

# %%
#サイズを調整
sns.set(font="meiryo",context="talk")
plt.figure(figsize=(10,8))
sns.barplot(data=df_score,y="名前",x="国語")
# Out:
# <AxesSubplot:xlabel='国語', ylabel='名前'>

# %%
#カラーパレットを変更
sns.set(font="meiryo",context="talk")
plt.figure(figsize=(10,8))
sns.barplot(data=df_score,y="名前",x="社会",palette="Blues")
# Out:
# <AxesSubplot:xlabel='社会', ylabel='名前'>

# %% [markdown]
# ### 3.ヒストグラム

# %%
df_score
# Out:
#      名前 クラス  性別  国語  算数  英語  理科  社会
# 0   Aさん  1組  男性  89  65  85  70  88
# 1   Bさん  3組  女性  67  56  81  46  78
# 2   Cさん  1組  男性  52  45  67  67  67
# 3   Dさん  2組  男性  45  96  50  80  67
# 4   Eさん  1組  男性  77  48  67  60  64
# 5   Fさん  2組  女性  60  73  83  60  53
# 6   Gさん  3組  男性  45  56  87  63  67
# 7   Hさん  2組  女性  81  65  90  45  70
# 8   Iさん  3組  女性  76  57  86  50  67
# 9   Jさん  2組  男性  44  96  56  89  71
# 10  Kさん  1組  女性  89  55  82  92  84
# 11  Lさん  2組  女性  31  37  76  45  50
# 12  Mさん  3組  男性  60  53  50  67  65
# 13  Nさん  2組  男性  71  98  81  91  99
# 14  Oさん  1組  男性  53  62  41  57  55
# 15  Pさん  2組  女性  89  83  69  57  44
# 16  Qさん  1組  男性  45  56  30  73  49
# 17  Rさん  3組  女性  64  56  76  50  69
# 18  Sさん  1組  女性  42  57  56  33  61
# 19  Tさん  2組  男性  76  90  66  67  89
# 20  Uさん  2組  男性  89  98  92  83  66
# 21  Vさん  1組  男性  65  58  62  50  53
# 22  Wさん  1組  男性  44  46  61  56  65
# 23  Xさん  3組  女性  76  56  34  65  67
# 24  Yさん  2組  男性  93  87  56  90  64
# ...

# %%
sns.histplot(data=df_score,x="理科")
# Out:
# <AxesSubplot:xlabel='理科', ylabel='Count'>

# %%
#棒（ビンズ）のレンジを0~100に設定
sns.histplot(data=df_score,
             x="理科",
             binrange=(0,100))
# Out:
# <AxesSubplot:xlabel='理科', ylabel='Count'>

# %%
#ビンズの数を設定（0~20）はいない
sns.histplot(data=df_score,
             x="理科",
             binrange=(0,100),
             bins=5)
# Out:
# <AxesSubplot:xlabel='理科', ylabel='Count'>

# %%
#ビンズの数を設定（0~20）はいない
sns.histplot(data=df_score,
             x="理科",
             binrange=(0,100),
             bins=10)
# Out:
# <AxesSubplot:xlabel='理科', ylabel='Count'>

# %%
#クラス別に情報を表示
sns.histplot(data=df_score,
             x="理科",
             binrange=(0,100),
             bins=10,
             hue="クラス")
# Out:
# <AxesSubplot:xlabel='理科', ylabel='Count'>

# %%
#クラス別の情報の順序を指定
sns.histplot(data=df_score,
             x="理科",
             binrange=(0,100),
             bins=10,
             hue="クラス",
             hue_order=["1組","2組","3組"])
# Out:
# <AxesSubplot:xlabel='理科', ylabel='Count'>

# %%
#重なっている表示方法を変更
sns.histplot(data=df_score,
             x="理科",
             binrange=(0,100),
             bins=10,
             hue="クラス",
             hue_order=["1組","2組","3組"],
             multiple="stack")
# Out:
# <AxesSubplot:xlabel='理科', ylabel='Count'>

# %%
#重なっている表示方法を変更（前に小さいもの、後ろに大きいもの）
sns.histplot(data=df_score,
             x="理科",
             binrange=(0,100),
             bins=10,
             hue="クラス",
             hue_order=["1組","2組","3組"],
             multiple="stack")
# Out:
# <AxesSubplot:xlabel='理科', ylabel='Count'>

# %%
#重なっている表示方法を変更（横並び）
sns.histplot(data=df_score,
             x="理科",
             binrange=(0,100),
             bins=10,
             hue="クラス",
             hue_order=["1組","2組","3組"],
             multiple="dodge")
# Out:
# <AxesSubplot:xlabel='理科', ylabel='Count'>

# %%
#見やすく調整
sns.histplot(data=df_score,
             x="理科",
             binrange=(0,100),
             bins=5,
             hue="クラス",
             hue_order=["1組","2組","3組"],
             multiple="dodge",
             shrink= 0.8)
# Out:
# <AxesSubplot:xlabel='理科', ylabel='Count'>

# %% [markdown]
# ### 4.散布図（とその仲間たち）

# %% [markdown]
# #### scatterplot:散布図

# %% [markdown]
# #### lmplot:回帰直線付き散布図

# %% [markdown]
# #### kdeplot:等高線風散布図

# %% [markdown]
# #### lmplot:回帰直線付き散布図

# %% [markdown]
# #### pairplot:全ペアによる散布図

# %% [markdown]
# ### 5.箱ひげ図

# %% [markdown]
# #### boxplot:箱ひげ図

# %% [markdown]
# #### violinplot:バイオリンプロット

# %% [markdown]
# #### stripplot:散布図風ヒストグラム

# %% [markdown]
# #### swarmplot:散布図風ヒストグラム２

# %% [markdown]
# ### 6.ヒートマップ

# %% [markdown]
# #### heatmap:ヒートマップ

# %% [markdown]
# #### clustermap:階層クラスタ付きヒートマップ
