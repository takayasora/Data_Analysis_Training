# %%
import pandas as pd

# %% [markdown]
# # 第一部：データの確認

# %% [markdown]
# ## 1.CSVの読み込み

# %%
df_enq = pd.read_csv("enquete_sample.csv")

# %%
df_enq
# Out:
#    回答者No.  性別   年代  世帯人数      年収  満足度
# 0    No.1  男性  40代     4   852.0    7
# 1    No.2  男性  30代     2   529.0    6
# 2    No.3  男性  20代     1   341.0    3
# 3    No.4  女性  40代     2   380.0    5
# 4    No.5  男性  50代     5   808.0    8
# 5    No.6  男性  50代     4   905.0   10
# 6    No.7  女性  50代     3   621.0    5
# 7    No.8  女性  50代     3   621.0    5
# 8    No.9  男性  20代     1   209.0    1
# 9   No.10  男性  NaN     3   517.0    8
# 10  No.11  男性  40代     4   560.0    6
# 11  No.12  男性  20代     2   403.0    7
# 12  No.13  女性  50代     4   501.0    5
# 13  No.14  女性  30代     1   391.0    5
# 14  No.15  女性  40代     3   679.0    6
# 15  No.16  男性  50代     3   615.0    8
# 16  No.17  女性  50代     4   544.0    1
# 17  No.18  女性  30代     3   443.0    7
# 18  No.19  男性  40代     3   502.0    6
# 19  No.20  男性  40代     5   900.0    9
# 20  No.21  女性  30代     3   707.0    6
# 21  No.22  女性  20代     1   286.0    9
# 22  No.23  女性  50代     3   429.0    6
# 23  No.24  男性  40代     4   811.0    3
# ...
